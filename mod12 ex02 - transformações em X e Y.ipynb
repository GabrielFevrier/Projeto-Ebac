# %% [markdown]
# # Regressão 01 - tarefa 02 - transformações em X e Y

# %%
import pandas as pd
import seaborn as sns
from seaborn import load_dataset

import matplotlib.pyplot as plt

import numpy as np

import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']

# %% [markdown]
# ### 1. Melhorando o ajuste no percentual de gorjetas
#
# a. Vamos partir do modelo feito na última tarefa, o que relaciona ```tip_pct``` e ```net_bill```. Carregue a base, os pacotes e reproduza este modelo aqui.

# %%
reg_tip = smf.ols('tip ~ net_bill', data = tips).fit()
reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     120.6
# Date:                Thu, 22 May 2025   Prob (F-statistic):           5.02e-23
# Time:                        14:55:03   Log-Likelihood:                -375.63
# No. Observations:                 244   AIC:                             755.3
# Df Residuals:                     242   BIC:                             762.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3307      0.168      7.907      0.000       0.999       1.662
# ...

# %% [markdown]
# ### 2. ajuste o modelo de ```tip_pct``` em função do logaritmo de ```net_bill```.

# %%
reg_tip = smf.ols('tip ~ np.log(net_bill)', data = tips).fit()
reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     101.0
# Date:                Thu, 22 May 2025   Prob (F-statistic):           4.40e-20
# Time:                        14:56:43   Log-Likelihood:                -382.40
# No. Observations:                 244   AIC:                             768.8
# Df Residuals:                     242   BIC:                             775.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ###  3. ajuste o modelo de ```tip_pct``` em função de um polinômio de segundo grau em ```net_bill```.

# %%
reg_tip = smf.ols('tip ~ np.power(net_bill,2)', data = tips).fit()
reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    tip   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     104.1
# Date:                Thu, 22 May 2025   Prob (F-statistic):           1.47e-20
# Time:                        14:57:33   Log-Likelihood:                -381.31
# No. Observations:                 244   AIC:                             766.6
# Df Residuals:                     242   BIC:                             773.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ###  4. ajuste um modelo no log do ```tip_pct``` em função de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```

# %%
reg_tip = smf.ols('net_bill ~ np.log(tip_pct)', data = tips).fit()
reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               net_bill   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     74.48
# Date:                Thu, 22 May 2025   Prob (F-statistic):           8.27e-16
# Time:                        17:57:45   Log-Likelihood:                -821.36
# No. Observations:                 244   AIC:                             1647.
# Df Residuals:                     242   BIC:                             1654.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
tips['pred'] = reg_tip.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0,1]

# %%
r**2
# Out:
# 0.5588632748879939

# %% [markdown]
# ###  5. ajuste um modelo no log do ```tip_pct``` em função do log de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```.

# %%
reg_tip = smf.ols('np.log(net_bill) ~ np.log(tip_pct)', data = tips).fit()
reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       np.log(net_bill)   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     100.5
# Date:                Thu, 22 May 2025   Prob (F-statistic):           5.20e-20
# Time:                        17:58:18   Log-Likelihood:                -123.41
# No. Observations:                 244   AIC:                             250.8
# Df Residuals:                     242   BIC:                             257.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
tips['pred'] = reg_tip.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0,1]

# %%
r**2
# Out:
# 0.5588632748879938

# %% [markdown]
# ###  6. qual modelo resultou no melhor ajuste?

# %%
Ambos os modelos apresentaram o mesmo R²
