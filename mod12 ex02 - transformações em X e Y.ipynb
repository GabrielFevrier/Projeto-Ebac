# %% [markdown]
# # Regressão 01 - tarefa 02 - transformações em X e Y

# %%
import pandas as pd
import seaborn as sns
from seaborn import load_dataset

import matplotlib.pyplot as plt

import numpy as np

import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset("tips")
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']

# %% [markdown]
# ### 1. Melhorando o ajuste no percentual de gorjetas
#
# a. Vamos partir do modelo feito na última tarefa, o que relaciona ```tip_pct``` e ```net_bill```. Carregue a base, os pacotes e reproduza este modelo aqui.

# %%
reg_tip = smf.ols('tip_pct ~ net_bill', data = tips).fit()
reg_tip.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tip_pct   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Sat, 24 May 2025   Prob (F-statistic):           1.52e-06
# Time:                        11:49:51   Log-Likelihood:                 108.00
# No. Observations:                 244   AIC:                            -212.0
# Df Residuals:                     242   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3053      0.023     13.166      0.000       0.260       0.351
# ...

# %% [markdown]
# ### 2. ajuste o modelo de ```tip_pct``` em função do logaritmo de ```net_bill```.

# %%
reg_tip1 = smf.ols('tip_pct ~ np.log(net_bill)', data = tips).fit()
reg_tip1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tip_pct   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     61.16
# Date:                Sat, 24 May 2025   Prob (F-statistic):           1.62e-13
# Time:                        11:52:31   Log-Likelihood:                 123.81
# No. Observations:                 244   AIC:                            -243.6
# Df Residuals:                     242   BIC:                            -236.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ###  3. ajuste o modelo de ```tip_pct``` em função de um polinômio de segundo grau em ```net_bill```.

# %%
reg_tip3 = smf.ols('tip_pct ~ np.power(net_bill,2)', data = tips).fit()
reg_tip3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tip_pct   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     13.48
# Date:                Sat, 24 May 2025   Prob (F-statistic):           0.000297
# Time:                        11:53:16   Log-Likelihood:                 102.94
# No. Observations:                 244   AIC:                            -201.9
# Df Residuals:                     242   BIC:                            -194.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ###  4. ajuste um modelo no log do ```tip_pct``` em função de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```

# %%
reg_tip4 = smf.ols('np.log(tip_pct) ~ net_bill', data = tips).fit()
reg_tip4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        np.log(tip_pct)   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     74.48
# Date:                Sat, 24 May 2025   Prob (F-statistic):           8.27e-16
# Time:                        11:55:41   Log-Likelihood:                -106.00
# No. Observations:                 244   AIC:                             216.0
# Df Residuals:                     242   BIC:                             223.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.2749      0.056    -22.872      0.000      -1.385      -1.165
# ...

# %%
tips['pred'] = reg_tip4.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0,1]

# %%
r**2
# Out:
# 0.09129084920662969

# %% [markdown]
# ###  5. ajuste um modelo no log do ```tip_pct``` em função do log de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```.

# %%
reg_tip5 = smf.ols('np.log(net_bill) ~ np.log(tip_pct)', data = tips).fit()
reg_tip5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       np.log(net_bill)   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     100.5
# Date:                Sat, 24 May 2025   Prob (F-statistic):           5.20e-20
# Time:                        11:57:00   Log-Likelihood:                -123.41
# No. Observations:                 244   AIC:                             250.8
# Df Residuals:                     242   BIC:                             257.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
tips['pred'] = reg_tip5.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0,1]

# %%
r**2
# Out:
# 0.5588632748879938

# %% [markdown]
# ###  6. qual modelo resultou no melhor ajuste?

# %%
O modelo com ambos ajustados ao log apresentar o melhor R²
